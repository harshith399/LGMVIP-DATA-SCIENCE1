# %% [markdown]
# <a href="https://colab.research.google.com/github/harshith399/LGMVIP-DATA-SCIENCE1/blob/main/image_to_pencil_sketch_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA-SCIENCE INTERN AT LETSGROWMORE LGMVIPJANUARY 2022
#
# NAME: KANUKUNTA HARSHITH GOUD
#
# TASK 2 - Image to Pencil Sketch with Python
#
# TASK 2

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image =cv2.imread("12345.png")

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1200 at 0x7F754F591110>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F754F529810>

# %%
inverted_gray_image = cv2.bitwise_not(gray_image)
cv2_imshow(inverted_gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F754F52F390>

# %%
inverted_blurry= cv2.GaussianBlur(inverted_gray_image, (21 ,21), sigmaX=0, sigmaY =0)
cv2_imshow(inverted_blurry)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F754F52FE10>

# %%
def dodgev2(x,y):
  return cv2.divide(x, 255 - y, scale = 256)

# %%
final_pencil_sketch = dodgev2(gray_image, inverted_blurry)
cv2_imshow(final_pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1200x1200 at 0x7F754F52F9D0>
